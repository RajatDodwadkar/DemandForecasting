# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.figure(dpi=600)

# %%
data = pd.read_csv("./medicine.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67024 entries, 0 to 67023
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   VAR         67024 non-null  object
#  1   Variable    67024 non-null  object
#  2   UNIT        67024 non-null  object
#  3   Measure     67024 non-null  object
#  4   COU         67024 non-null  object
#  5   Country     67024 non-null  object
#  6   YEA         67024 non-null  int64
#  7   Year        67024 non-null  int64
#  8   Value       67024 non-null  float64
#  9   Flag Codes  32486 non-null  object
#  10  Flags       32486 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 5.6+ MB

# %%
data.describe()
# Out:
#                 YEA          Year         Value
# count  67024.000000  67024.000000  6.702400e+04
# mean    2015.295834   2015.295834  1.333831e+04
# std        3.318053      3.318053  3.710317e+05
# min     2010.000000   2010.000000  0.000000e+00
# 25%     2012.000000   2012.000000  5.100000e+00
# 50%     2015.000000   2015.000000  2.400000e+01
# 75%     2018.000000   2018.000000  1.242000e+02
# max     2021.000000   2021.000000  3.252220e+07

# %%
data.head()
# Out:
#         VAR                           Variable      UNIT  \
# 0  PHARALIM  A-Alimentary tract and metabolism  NBPYEANB
# 1  PHARALIM  A-Alimentary tract and metabolism  NBPYEANB
# 2  PHARALIM  A-Alimentary tract and metabolism  NBPYEANB
# 3  PHARALIM  A-Alimentary tract and metabolism  NBPYEANB
# 4  PHARALIM  A-Alimentary tract and metabolism  NBPYEANB
#
#                                              Measure  COU    Country   YEA  \
# 0  Defined daily dosage per 1 000 inhabitants per...  AUS  Australia  2010
# 1  Defined daily dosage per 1 000 inhabitants per...  AUS  Australia  2011
# 2  Defined daily dosage per 1 000 inhabitants per...  AUS  Australia  2012
# 3  Defined daily dosage per 1 000 inhabitants per...  AUS  Australia  2013
# 4  Defined daily dosage per 1 000 inhabitants per...  AUS  Australia  2014
#
#    Year  Value Flag Codes                             Flags
# 0  2010  145.8          D         Difference in methodology
# ...

# %%
# Selected Variables with `UNIT`= 'NBPYEANB'
variables = ['A-Alimentary tract and metabolism',
 'A02B-Drugs for peptic ulcer and gastro-oesophageal reflux diseases (GORD)',
 'A10-Drugs used in diabetes',
 'B-Blood and blood forming organs',
 'C-Cardiovascular system',
 'C01A-Cardiac glycosides',
 'C01B-Antiarrhythmics, Class I and III',
 'C02-Antihypertensives',
 'C03-Diuretics',
 'C07-Beta blocking agents',
 'C08-Calcium channel blockers',
 'C09-Agents acting on the Renin-Angiotensin system',
 'C10-Lipid modifying agents',
 'G-Genito urinary system and sex hormones',
 'G03-Sex hormones and modulators of the genital system',
 'H-Systemic hormonal preparations, excluding sex hormones and insulins',
 'J-Antiinfectives for systemic use',
 'J01-Antibacterials for systemic use',
 'M-Musculo-skeletal system',
 'M01A-Antiinflammatory and antirheumatic products non-steroids',
 'N-Nervous system',
 'N02-Analgesics',
 'N05B-Anxiolytics',
 'N05C-Hypnotics and sedatives',
 'N06A-Antidepressants',
 'R-Respiratory system',
 'R03-Drugs for obstructive airway diseases']

# %%
data = data.loc[(data['UNIT'] == 'NBPYEANB') & (data['Variable'].isin(variables))]
data.to_csv("processed.csv", index=False)

# %%
new_data = pd.read_csv("processed.csv")
for i in variables:
    df = new_data.loc[(new_data['Variable'] == i) & (new_data['Country'] == 'Australia' )]
    plt.plot(df['Year'], df['Value'], label=i)
    plt.legend()
    plt.show()
